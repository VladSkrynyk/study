# %% [markdown]
# <dl>
#   <dt>First Term</dt>
#   $y'$ = $y^2 + x - 2$
#   <dt>Second Term</dt>
#   <dd>This is one definition of the second term. </dd>
#   <dd>This is another definition of the second term.</dd>
# </dl>

# %%
#from pylab import *
import numpy as np
from matplotlib import pyplot as plt

x = np.arange(-10, 10, 0.1)
y1 = np.sqrt(-x + 2)
y2 = -np.sqrt(-x + 2)

plt.plot(x, y1)
plt.plot(x, y2)

plt.show()
# Out:
# C:\Users\skryn\AppData\Local\Temp\ipykernel_12932\811945953.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(-x + 2)
# C:\Users\skryn\AppData\Local\Temp\ipykernel_12932\811945953.py:7: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -np.sqrt(-x + 2)
