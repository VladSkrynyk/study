# %% [markdown]
# # Лабораторна робота 1

# %% [markdown]
# 12. $y'$ = $y^2 + x - 2$

# %%
from matplotlib import pyplot as plt # підключаємо необхідні бібліотеки
import numpy as np

# %% [markdown]
# 1. Зобразити поле напрямкiв в точках (m, $\frac{n}{2}$) m = -6, -5, ..., 6;  n = -6, -5, ... 6

# %%
def task1():
    xmax = 6.0
    xmin = -xmax
    D = 13
    ymax = 3.0
    ymin = -ymax
    x = np.linspace(xmin, xmax, D)
    y = np.linspace(ymin, ymax, D)
    X, Y = np.meshgrid(x, y)
    deg = np.arctan(Y**2 + X - 2)
    QP = plt.quiver(X,Y,np.cos(deg),np.sin(deg))
    plt.show()

task1()

# %% [markdown]
# 2. Описати аналітично та зобразити множину точок максимуму розв'зків

# %%
def task2():
    print('test')

task2()
# Out:
# test

# %% [markdown]
# Точки max:
# $$
#   \begin{cases}
#       y' = 0  \\
#       y'' > 0
#   \end{cases}
# $$
#
# $$
#   \begin{cases}
#     x = 2 - y^2 \\
#     \sqrt{2} > 0
#   \end{cases}
# $$

# %%
def task2():
    x = np.arange(-6, 6, 0.01)

    y1 = np.sqrt(2 - x)
    y2 = -1 * np.sqrt(2 - x)

    plt.plot(x, y1, color="r")
    plt.plot(x, y2, color="r")

    task1()
    plt.show()

task2()
# Out:
# C:\Users\skryn\AppData\Local\Temp\ipykernel_15840\675548926.py:4: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(2 - x)
# C:\Users\skryn\AppData\Local\Temp\ipykernel_15840\675548926.py:5: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -1 * np.sqrt(2 - x)

# %% [markdown]
# 3. Зобразити ізокліни які характеризуються такими коефіцієнтами k = $\pm$ $\frac{1}{2}$, $\pm$ 1, $\pm$ $\frac{3}{2}$

# %%
def task3():
    x = np.arange(-6, 6, 0.01)
    k = [[1, -1], [0.5, -0.5], [1.5, -1.5]]

    for ki in k:
        y1 = np.sqrt(2 + ki[0] - x)
        y2 = -1 * np.sqrt(2 + ki[0] - x)

        plt.plot(x, y1, color="b", label=f"x = {2 + ki[0]} - x")
        plt.plot(x, y2, color="b", label=f"x = {2 + ki[0]} - x")

        y1 = np.sqrt(2 + ki[1] - x)
        y2 = -1 * np.sqrt(2 + ki[1] - x)

        plt.plot(x, y1, color="b", label=f"x = {2 + ki[1]} - x")
        plt.plot(x, y2, color="b", label=f"x = {2 + ki[1]} - x")

    task2()
    plt.show()

task3()
# Out:
# C:\Users\skryn\AppData\Local\Temp\ipykernel_15840\2628975629.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(2 + ki[0] - x)
# C:\Users\skryn\AppData\Local\Temp\ipykernel_15840\2628975629.py:7: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -1 * np.sqrt(2 + ki[0] - x)
# C:\Users\skryn\AppData\Local\Temp\ipykernel_15840\2628975629.py:12: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(2 + ki[1] - x)
# C:\Users\skryn\AppData\Local\Temp\ipykernel_15840\2628975629.py:13: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -1 * np.sqrt(2 + ki[1] - x)
# C:\Users\skryn\AppData\Local\Temp\ipykernel_15840\675548926.py:4: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(2 - x)
# C:\Users\skryn\AppData\Local\Temp\ipykernel_15840\675548926.py:5: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -1 * np.sqrt(2 - x)
